# %%
# Dependencies
import pandas as pd

# %%
# List of file names to be combined
files_2022 = ['Data/JC-202201-citibike-tripdata.csv', 'Data/JC-202202-citibike-tripdata.csv', 'Data/JC-202203-citibike-tripdata.csv', 'Data/JC-202204-citibike-tripdata.csv', 'Data/JC-202205-citibike-tripdata.csv', 'Data/JC-202206-citibike-tripdata.csv', 'Data/JC-202207-citbike-tripdata.csv', 'Data/JC-202208-citibike-tripdata.csv', 'Data/JC-202209-citibike-tripdata.csv', 'Data/JC-202210-citibike-tripdata.csv', 'Data/JC-202211-citibike-tripdata.csv', 'Data/JC-202212-citibike-tripdata.csv']

# Create an empty list to store each dataframe
citiBike2022_list = []

# Loop through each file in the list
for file in files_2022:
    # Read the file into a dataframe
    citiBike2022 = pd.read_csv(file)
    
    # Append the dataframe to the list
    citiBike2022_list.append(citiBike2022)
    
# Concatenate all dataframes in the list into one dataframe
citiBike2022 = pd.concat(citiBike2022_list)

# Show the combined dataframe
citiBike2022
# Out:
#                 ride_id  rideable_type           started_at  \
# 0      CA5837152804D4B5  electric_bike  2022-01-26 18:50:39
# 1      BA06A5E45B6601D2   classic_bike  2022-01-28 13:14:07
# 2      7B6827D7B9508D93   classic_bike  2022-01-10 19:55:13
# 3      6E5864EA6FCEC90D  electric_bike  2022-01-26 07:54:57
# 4      E24954255BBDE32D  electric_bike  2022-01-13 18:44:46
# ...                 ...            ...                  ...
# 48580  D438F1622839AC50   classic_bike  2022-12-06 15:43:38
# 48581  747A63A8E782D171  electric_bike  2022-12-08 08:17:51
# 48582  AE090858CFDE6E82  electric_bike  2022-12-23 14:10:07
# 48583  B3CC8E70AF4E259C   classic_bike  2022-12-02 04:43:25
# 48584  176B601F21327350   classic_bike  2022-12-30 14:50:17
#
#                   ended_at                      start_station_name  \
# 0      2022-01-26 18:51:53                    12 St & Sinatra Dr N
# 1      2022-01-28 13:20:23                        Essex Light Rail
# ...

# %%
# List of file names to be combined
files_2023 = ['Data/JC-202301-citibike-tripdata.csv', 'Data/JC-202302-citibike-tripdata.csv', 'Data/JC-202303-citibike-tripdata.csv', 'Data/JC-202304-citibike-tripdata.csv', 'Data/JC-202305-citibike-tripdata.csv', 'Data/JC-202306-citibike-tripdata.csv', 'Data/JC-202307-citibike-tripdata.csv']
# Create an empty list to store each dataframe
citiBike2023_list = []

# Loop through each file in the list
for file in files_2023:
    # Read the file into a dataframe
    citiBike2023 = pd.read_csv(file)
    
    # Append the dataframe to the list
    citiBike2023_list.append(citiBike2023)
    
# Concatenate all dataframes in the list into one dataframe
citiBike2023 = pd.concat(citiBike2023_list)

# Show the combined dataframe
citiBike2023
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       0905B18B365C9D20   classic_bike  2023-01-28 09:18:10
# 1       B4F0562B05CB5404  electric_bike  2023-01-23 20:10:12
# 2       5ABF032895F5D87E   classic_bike  2023-01-29 15:27:04
# 3       E7E1F9C53976D2F9   classic_bike  2023-01-24 18:35:08
# 4       323165780CA0734B   classic_bike  2023-01-21 20:44:09
# ...                  ...            ...                  ...
# 106603  944F5CD711E7688E   classic_bike  2023-07-25 18:21:52
# 106604  4665B542F79F8C43  electric_bike  2023-07-26 22:22:20
# 106605  789D45FDEBC19E83   classic_bike  2023-07-31 07:57:29
# 106606  FFBE463288D36C2A   classic_bike  2023-07-07 17:52:09
# 106607  4DACECF4EBBEB60C   classic_bike  2023-07-26 20:54:16
#
#                    ended_at                        start_station_name  \
# 0       2023-01-28 09:28:52  Hoboken Terminal - Hudson St & Hudson Pl
# 1       2023-01-23 20:18:27  Hoboken Terminal - Hudson St & Hudson Pl
# ...

# %%
# Dataframes into one
CitiBike2022_2023 = pd.concat([citiBike2022, citiBike2023], axis=0)

#Display the results
CitiBike2022_2023
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       CA5837152804D4B5  electric_bike  2022-01-26 18:50:39
# 1       BA06A5E45B6601D2   classic_bike  2022-01-28 13:14:07
# 2       7B6827D7B9508D93   classic_bike  2022-01-10 19:55:13
# 3       6E5864EA6FCEC90D  electric_bike  2022-01-26 07:54:57
# 4       E24954255BBDE32D  electric_bike  2022-01-13 18:44:46
# ...                  ...            ...                  ...
# 106603  944F5CD711E7688E   classic_bike  2023-07-25 18:21:52
# 106604  4665B542F79F8C43  electric_bike  2023-07-26 22:22:20
# 106605  789D45FDEBC19E83   classic_bike  2023-07-31 07:57:29
# 106606  FFBE463288D36C2A   classic_bike  2023-07-07 17:52:09
# 106607  4DACECF4EBBEB60C   classic_bike  2023-07-26 20:54:16
#
#                    ended_at    start_station_name start_station_id  \
# 0       2022-01-26 18:51:53  12 St & Sinatra Dr N            HB201
# 1       2022-01-28 13:20:23      Essex Light Rail            JC038
# ...

# %%
# Save the dataframe to a CSV file
CitiBike2022_2023.to_csv('data/citibike.csv', index=False)
